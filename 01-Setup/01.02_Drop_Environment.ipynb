# %% [markdown]
# ## Excluir ambiente
# - Realiza o DROP do Schema e todos os seus objetos

# %%
# %run ../common/setenv

# %%
# Drop Schema
# Ref.: https://docs.databricks.com/aws/pt/schemas/manage-schema#excluir-um-esquema

spark.sql(f"DROP SCHEMA {settings['lab.catalog']}.{settings['lab.schema']} CASCADE;")
