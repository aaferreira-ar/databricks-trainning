-- %% [markdown]
-- ## Exemplo DLT
-- - Carregar Clientes
-- - Carregar Vendas
-- - Gerar View Materializada: Vendas por Clientes

-- %%
CREATE OR REFRESH STREAMING TABLE example_csv_table
AS SELECT * FROM read_files('/path/to/csv/files', 'csv');
