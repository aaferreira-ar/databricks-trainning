# %% [markdown]
# ## Exemplo DLT
# - Carregar Clientes
# - Carregar Vendas
# - Gerar View Materializada: Vendas por Clientes

# %%
# %run ../common/setenv

# %% [markdown]
# - Neste exercício serão utilizados arquivos pre-gerados no volume {lab.path.files}/generate
# - Serão usados os seguintes notebooks
# - 1o carga base clientes
# - 2o carga operações
# - 3o geração resumo vendas por cliente

# %%
import shutil
import os
from time import sleep

# %%
files_path = f"{settings['lab.path.files']}/dlt/customers"
os.makedirs(files_path, exist_ok=True)

files_path = f"{settings['lab.path.files']}/dlt/sales"
os.makedirs(files_path, exist_ok=True)

# %%
dbutils.fs.cp(f"{settings['lab.path.files']}/generated/customers", f"{settings['lab.path.files']}/dlt/customers", True)

# %%
# %sql
DROP table lakehouse.lab_aaferreira_lab06.sales;
DROP table lakehouse.lab_aaferreira_lab06.customers;

# %%
sales_files = dbutils.fs.ls(f"{settings['lab.path.files']}/generated/sales")
display(sales_files)
len(sales_files)

# %%
for file in sales_files:
  file_copy = str(file.path).replace("generated", "dlt")
  dbutils.fs.mv(file.path, file_copy)
  print("Arquivo copiado ", file_copy)
  sleep(60)
